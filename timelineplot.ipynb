# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# %%
dates = ['1590','1665','1835','1868','1883','1900','1930','1955','1858','1873','1884','1871','1852','1941']
events = ['First microscope invented','Robert Hooke and Antonj van Leeuwenhoek use microscopes for scientific discovery',
          'The Airy disc is theorized by George Airy','Ernst Abbe invents the apochromatic lens','First diffraction-limited microscope created',
          'Kohler Illumination becomes the basis of modern brightfield mircoscopes','Fritz Zernike develops phase contrast imaging',
          'DIC imaging developed by George Nomarski','Carmine staining','Silver staining','Gram staining','First fluorescence stain','Stokes shift described','First fluorescently labeled antibody used']
